# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.fillna(df.mean())
# Out:
#     Marketing Spend  Administration      Transport     Area     Profit
# 0         114523.61       136897.80  471784.100000    Dhaka  192261.83
# 1         162597.70       151377.59  443898.530000      Ctg  191792.06
# 2         153441.51       101145.55  407934.540000  Rangpur  191050.39
# 3         144372.41       118671.85  383199.620000    Dhaka  182901.99
# 4         142107.34        91391.77  366168.420000  Rangpur  166187.94
# 5         131876.90        99814.71  362861.360000    Dhaka  156991.12
# 6         134615.46       147198.87  127716.820000      Ctg  156122.51
# 7         130298.13       145530.06  323876.680000  Rangpur  155752.60
# 8         120542.52       148718.95  311613.290000    Dhaka  152211.77
# 9         123334.88       108679.17  304981.620000      Ctg  149759.96
# 10        101913.08       110594.11  229160.950000  Rangpur  146121.95
# 11        100671.96        91790.61  249744.550000      Ctg  144259.40
# ...

# %%
df1=df.copy()
df2=df.copy()
df3=df.copy()

# %%
df4=df.copy()

# %%
from sklearn.preprocessing import RobustScaler
RS=RobustScaler()

# %%
df1['Marketing Spend']=RS.fit_transform(df1[['Marketing Spend']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Administration']=RS.fit_transform(df1[['Administration']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355  471784.10    Dhaka  192261.83
# 1         1.452113        0.697565  443898.53      Ctg  191792.06
# 2         1.303634       -0.524290  407934.54  Rangpur  191050.39
# 3         1.156567       -0.097977  383199.62    Dhaka  182901.99
# 4         1.119836       -0.761543  366168.42  Rangpur  166187.94

# %%
df1['Transport']=RS.fit_transform(df1[['Transport']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355   1.552016    Dhaka  192261.83
# 1         1.452113        0.697565   1.383714      Ctg  191792.06
# 2         1.303634       -0.524290   1.166654  Rangpur  191050.39
# 3         1.156567       -0.097977   1.017368    Dhaka  182901.99
# 4         1.119836       -0.761543   0.914576  Rangpur  166187.94

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
ad=scaler.fit(df2[['Administration']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df2['Administration']=scaler.transform(df2[['Administration']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.651744  471784.10    Dhaka  192261.83
# 1        162597.70        0.761972  443898.53      Ctg  191792.06
# 2        153441.51        0.379579  407934.54  Rangpur  191050.39
# 3        144372.41        0.512998  383199.62    Dhaka  182901.99
# 4        142107.34        0.305328  366168.42  Rangpur  166187.94

# %%
df2['Marketing Spend']=scaler.transform(df2[['Marketing Spend']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.481420        0.651744  471784.10    Dhaka  192261.83
# 1         0.847385        0.761972  443898.53      Ctg  191792.06
# 2         0.777683        0.379579  407934.54  Rangpur  191050.39
# 3         0.708645        0.512998  383199.62    Dhaka  182901.99
# 4         0.691402        0.305328  366168.42  Rangpur  166187.94

# %%
df2['Transport']=scaler.transform(df2[['Transport']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.481420        0.651744   3.201075    Dhaka  192261.83
# 1         0.847385        0.761972   2.988795      Ctg  191792.06
# 2         0.777683        0.379579   2.715018  Rangpur  191050.39
# 3         0.708645        0.512998   2.526723    Dhaka  182901.99
# 4         0.691402        0.305328   2.397073  Rangpur  166187.94

# %% [markdown]
# # Max()

# %%
df.Transport=df.Transport/df.Transport.max()
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.000000    Dhaka  192261.83
# 1        162597.70       151377.59   0.940893      Ctg  191792.06
# 2        153441.51       101145.55   0.864664  Rangpur  191050.39
# 3        144372.41       118671.85   0.812235    Dhaka  182901.99
# 4        142107.34        91391.77   0.776136  Rangpur  166187.94

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
st_scaler=StandardScaler()

# %%
df3['Marketing Spend'] = st_scaler.fit_transform(df3[['Marketing Spend']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df3['Administration'] = st_scaler.fit_transform(df3[['Administration']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753  471784.10    Dhaka  192261.83
# 1         1.955860        1.082807  443898.53      Ctg  191792.06
# 2         1.754364       -0.728257  407934.54  Rangpur  191050.39
# 3         1.554784       -0.096365  383199.62    Dhaka  182901.99
# 4         1.504937       -1.079919  366168.42  Rangpur  166187.94

# %%
df3['Transport'] = st_scaler.fit_transform(df3[['Transport']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.165287    Dhaka  192261.83
# 1         1.955860        1.082807   1.929843      Ctg  191792.06
# 2         1.754364       -0.728257   1.626191  Rangpur  191050.39
# 3         1.554784       -0.096365   1.417348    Dhaka  182901.99
# 4         1.504937       -1.079919   1.273550  Rangpur  166187.94

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
max_scaler=MaxAbsScaler()

# %%
df4['Marketing Spend']=max_scaler.fit_transform(df4[['Marketing Spend']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df4['Administration']=max_scaler.fit_transform(df4[['Administration']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527  471784.10    Dhaka  192261.83
# 1         0.983359        0.828805  443898.53      Ctg  191792.06
# 2         0.927985        0.553781  407934.54  Rangpur  191050.39
# 3         0.873136        0.649738  383199.62    Dhaka  182901.99
# 4         0.859438        0.500378  366168.42  Rangpur  166187.94

# %%
df4['Transport']=max_scaler.fit_transform(df4[['Transport']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94
